# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmineeeee/python/blob/main/%EB%85%BC%ED%94%84_%EA%B3%BC%EC%A0%9C_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,2,0.01)
y = x**2+np.sin(3*x+7)

plt.plot(x,y)

plt.show()
